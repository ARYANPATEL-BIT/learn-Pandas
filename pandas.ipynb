# %%
import pandas as pd

# %%
import numpy as np

# %%
data = {
    'students': ['navneet','rohit'],
    'subject': ['python', 'html'],
    'marks':[89,90]
}

# %%
data2 = {
    'students' : ['human','unknown'],
    'subject': ['dont know','life and death'],
    'marks': [99, 100]
}

# %%
df1 = pd.DataFrame(data)

# %%
df2 = pd.DataFrame(data2)

# %%
pd.concat([df1,df2])
# Out:
#   students         subject  marks
# 0  navneet          python     89
# 1    rohit            html     90
# 0    human       dont know     99
# 1  unknown  life and death    100

# %%
data3 = pd.DataFrame({
    'students': ['navneet','rohit','aryan', 'Unknown'],
    'subject': ['python', 'html', 'ML', 'AI'],
    'marks':[89,90, 100, 100]
}) 

data4 = pd.DataFrame({
    'Roll': [101,102,103,104],
    'Ranks': [99,100,1,1]
})

result = data3.join(data4)

# %%
print(result)
# Out:
#   students subject  marks  Roll  Ranks
# 0  navneet  python     89   101     99
# 1    rohit    html     90   102    100
# 2    aryan      ML    100   103      1
# 3  Unknown      AI    100   104      1

# %%
result.loc[0,["students","subject","Roll"]]
# Out:
# students    navneet
# subject      python
# Roll            101
# Name: 0, dtype: object

# %%
result.iloc[[1,3],4]
# Out:
# 1    100
# 3      1
# Name: Ranks, dtype: int64

# %%
humans = {
    'students' :['Aryan',"unknow"],
    'subjects' : ['python','ml'],
    'marks' : [100,100]
}

beings = {
    'humanity' : ['human','human'],
    "empathy" : ["yes", "yes"]
}

# %%
humans = pd.DataFrame(humans)
beings = pd.DataFrame(beings)

# %%
pd.concat([humans,beings], ignore_index=True)
# Out:
#   students subjects  marks humanity empathy
# 0    Aryan   python  100.0      NaN     NaN
# 1   unknow       ml  100.0      NaN     NaN
# 2      NaN      NaN    NaN    human     yes
# 3      NaN      NaN    NaN    human     yes

# %%
data1 = {
    'students' : ['Aryan', 'Unknow'],
    'subjects' : ['python', 'Python'],
    'marks' : [100, 100]
}

data2 = {
    "students" : ['human', "being"],
    'subjects' : ['empathy', 'humanity'],
    'marks': [100, 100]
}

# %%
d1 = pd.DataFrame(data1)
d2 = pd.DataFrame(data2)

# %%
pd.concat([d1,d2], ignore_index=True)
# Out:
#   students  subjects  marks
# 0    Aryan    python    100
# 1   Unknow    Python    100
# 2    human   empathy    100
# 3    being  humanity    100

# %%
# Series

# %%
data = pd.Series(['Bulvasaur','Ivysaur','Venusaur','Charmander','Charmelion','Charlizard'])

# %%
data
# Out:
# 0     Bulvasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmelion
# 5    Charlizard
# dtype: str

# %%
pokemons = { 1: "Bulvasaur",2:"Ivysaur",3:"Venusaur",4:"Charmander",5:"Charmelion",6:"Charlizard"}

# %%
print(pd.Series(pokemons))
# Out:
# 1     Bulvasaur
# 2       Ivysaur
# 3      Venusaur
# 4    Charmander
# 5    Charmelion
# 6    Charlizard
# dtype: str

# %%
# Masking

att = np.array([100,74,79,75,34,27,89])

att
# Out:
# array([100,  74,  79,  75,  34,  27,  89])

# %%
mask = att>74

mask
# Out:
# array([ True, False,  True,  True, False, False,  True])

# %%
data1 ={
    'Students':["aryan",'unknown','arun','april'],
    'Subjects':['python','html','java','rust'],
    'marks':[100,99,98,99]
}

df = pd.DataFrame(data1)
df
# Out:
#   Students Subjects  marks
# 0    aryan   python    100
# 1  unknown     html     99
# 2     arun     java     98
# 3    april     rust     99

# %%
df.insert(1,'Roll',[1,2,3,4])
df
# Out:
#   Students  Roll Subjects  marks
# 0    aryan     1   python    100
# 1  unknown     2     html     99
# 2     arun     3     java     98
# 3    april     4     rust     99

# %%
df.assign(City=['Kanpur','Delhi','Pune','Blr'])
# Out:
#   Students Subjects  marks    City
# 0    aryan   python    100  Kanpur
# 1  unknown     html     99   Delhi
# 2     arun     java     98    Pune
# 3    april     rust     99     Blr

# %%
df.drop('Roll',axis=1,inplace=True)
df
# Out:
#   Students Subjects  marks
# 0    aryan   python    100
# 1  unknown     html     99
# 2     arun     java     98
# 3    april     rust     99

# %%
df.drop(0,axis=0)
# Out:
#   Students Subjects  marks
# 1  unknown     html     99
# 2     arun     java     98
# 3    april     rust     99

# %%
for r in df.iterrows():
    print(r)
# Out:
# (0, Students     aryan
# Subjects    python
# marks          100
# Name: 0, dtype: object)
# (1, Students    unknown
# Subjects       html
# marks            99
# Name: 1, dtype: object)
# (2, Students    arun
# Subjects    java
# marks         98
# Name: 2, dtype: object)
# (3, Students    april
# Subjects     rust
# marks          99
# Name: 3, dtype: object)

# %%
for r in df.itertuples():
    print(r)
# Out:
# Pandas(Index=0, Students='aryan', Subjects='python', marks=100)
# Pandas(Index=1, Students='unknown', Subjects='html', marks=99)
# Pandas(Index=2, Students='arun', Subjects='java', marks=98)
# Pandas(Index=3, Students='april', Subjects='rust', marks=99)

# %%
df.sort_values(by='marks')
# Out:
#   Students Subjects  marks
# 2     arun     java     98
# 1  unknown     html     99
# 3    april     rust     99
# 0    aryan   python    100

# %%
df.sort_values(by='marks', ascending=False)
# Out:
#   Students Subjects  marks
# 0    aryan   python    100
# 1  unknown     html     99
# 3    april     rust     99
# 2     arun     java     98

# %%
df.duplicated()
df.duplicated(subset=['Students'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#   Students Subjects  marks
# 0    aryan   python    100
# 1  unknown     html     99
# 2     arun     java     98
# 3    april     rust     99

# %%
data = {
    'EmployeeID':[101,102,103,104,105],
    'Employee':['Amit','Neha','Rahul','Sneha','Akit'],
    'Department':['HR','IT','IT','HR','SALES'],
    'Salary':[50000, 70000,65000,55000,60000]
}

df = pd.DataFrame(data)
df
# Out:
#    EmployeeID Employee Department  Salary
# 0         101     Amit         HR   50000
# 1         102     Neha         IT   70000
# 2         103    Rahul         IT   65000
# 3         104    Sneha         HR   55000
# 4         105     Akit      SALES   60000

# %%
grp = df.groupby('Department')
grp.first()
# Out:
#             EmployeeID Employee  Salary
# Department
# HR                 101     Amit   50000
# IT                 102     Neha   70000
# SALES              105     Akit   60000

# %%
grp.get_group("HR")
# Out:
#    EmployeeID Employee Department  Salary
# 0         101     Amit         HR   50000
# 3         104    Sneha         HR   55000

# %%
grp.get_group("SALES")
# Out:
#    EmployeeID Employee Department  Salary
# 4         105     Akit      SALES   60000

# %%
grp.sum(numeric_only=True)
# Out:
#             EmployeeID  Salary
# Department
# HR                 205  105000
# IT                 205  135000
# SALES              105   60000

# %%
grp.mean(numeric_only=True)
# Out:
#             EmployeeID   Salary
# Department
# HR               102.5  52500.0
# IT               102.5  67500.0
# SALES            105.0  60000.0

# %%
grp.max()
# Out:
#             EmployeeID Employee  Salary
# Department
# HR                 104    Sneha   55000
# IT                 103    Rahul   70000
# SALES              105     Akit   60000

# %%
grp.min()
# Out:
#             EmployeeID Employee  Salary
# Department
# HR                 101     Amit   50000
# IT                 102     Neha   65000
# SALES              105     Akit   60000

# %%
grp.count()
# Out:
#             EmployeeID  Employee  Salary
# Department
# HR                   2         2       2
# IT                   2         2       2
# SALES                1         1       1

# %%
df1 = pd.DataFrame({
    'EmployeeID':[101,102,103],
    'Employee':['Amit','Neha','Rahul']
})

df2 = pd.DataFrame({
    'EmployeeID':[102,103,104],
    'Department':['IT','IT','HR']
})

# %%
pd.merge(df1,df2,on='EmployeeID', how='inner')
# Out:
#    EmployeeID Employee Department
# 0         102     Neha         IT
# 1         103    Rahul         IT

# %%
pd.merge(df1,df2,on='EmployeeID',how='left')
# Out:
#    EmployeeID Employee Department
# 0         101     Amit        NaN
# 1         102     Neha         IT
# 2         103    Rahul         IT

# %%
pd.merge(df1,df2,on='EmployeeID',how='right')
# Out:
#    EmployeeID Employee Department
# 0         102     Neha         IT
# 1         103    Rahul         IT
# 2         104      NaN         HR

# %%
pd.merge(df1,df2,on="EmployeeID",how='outer')
# Out:
#    EmployeeID Employee Department
# 0         101     Amit        NaN
# 1         102     Neha         IT
# 2         103    Rahul         IT
# 3         104      NaN         HR

# %%
df[df['Salary'] >= 60000]
# Out:
#    EmployeeID Employee Department  Salary
# 1         102     Neha         IT   70000
# 2         103    Rahul         IT   65000
# 4         105     Akit      SALES   60000

# %%
df[df['Department'] == 'IT']
# Out:
#    EmployeeID Employee Department  Salary
# 1         102     Neha         IT   70000
# 2         103    Rahul         IT   65000

# %%
df[(df['Department']== "HR") & (df['Salary'] > 50000 )]
# Out:
#    EmployeeID Employee Department  Salary
# 3         104    Sneha         HR   55000

# %%
df[df['Department'].isin(['HR',"SALES"])]
# Out:
#    EmployeeID Employee Department  Salary
# 0         101     Amit         HR   50000
# 3         104    Sneha         HR   55000
# 4         105     Akit      SALES   60000

# %%
df[df['Employee'].str.contains('a',case=False)]
# Out:
#    EmployeeID Employee Department  Salary
# 0         101     Amit         HR   50000
# 1         102     Neha         IT   70000
# 2         103    Rahul         IT   65000
# 3         104    Sneha         HR   55000
# 4         105     Akit      SALES   60000

# %%
df[df['Employee'].str.contains('n', case=True)]
# Out:
#    EmployeeID Employee Department  Salary
# 3         104    Sneha         HR   55000
